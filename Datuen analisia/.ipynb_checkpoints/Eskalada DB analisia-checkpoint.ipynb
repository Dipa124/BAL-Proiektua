# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
eskaladaDB = pd.read_csv("Eskalada DB.csv")
eskaladaDB
# Out:
#           SEXUA             IZENA   ABIZENA  ADINA ADIN TARTEA  ESKARMENTUA  \
# 0        Gizona             PABLO   SERRANO   25.0      Gaztea          3.0
# 1        Gizona         JOSE LUIS      RUIZ   38.0      Heldua          3.0
# 2      Emakumea             MARIA     BRAVO   15.0     Nerabea          7.0
# 3      Emakumea      MARIA ISABEL      LEON   16.0     Nerabea          0.0
# 4        Gizona  FRANCISCO JAVIER  GALLARDO   14.0     Nerabea          6.0
# ...         ...               ...       ...    ...         ...          ...
# 11995    Gizona           JOAQUIN     NIETO   53.0      Heldua          0.0
# 11996    Gizona             RUBEN   MORALES   21.0      Gaztea          1.0
# 11997    Gizona             RAMON     REYES   36.0      Heldua          9.0
# 11998    Gizona             MIKEL     DURAN   29.0      Gaztea          8.0
# 11999    Gizona        JOSE MARIA     LOPEZ   30.0      Gaztea          7.0
#
#        ALTUERA   MASA         MAILA    ESTILOA   PRESA
# 0        179.0  87.96    Aurreratua  Dinamikoa   Crimp
# 1        183.0  77.13    Aurreratua    Nahasia   Crack
# 2        162.0  57.35    Aurreratua    Nahasia  Sloper
# 3        158.0  46.72    Hasiberria    Nahasia     Jug
# 4        169.0  67.99    Aurreratua  Dinamikoa  Volume
# ...        ...    ...           ...        ...     ...
# 11995    181.0  70.24    Aurreratua  Estatikoa   Pinch
# 11996    160.0  79.49       Erdikoa  Dinamikoa   Crimp
# 11997    177.0  76.12    Aurreratua  Estatikoa   Pinch
# 11998    164.0  70.94  Profesionala  Dinamikoa   Crimp
# 11999    173.0  75.51        Elitea  Dinamikoa    Edge
#
# [12000 rows x 11 columns]

# %%
eskaladaDB.dtypes
# Out:
# SEXUA           object
# IZENA           object
# ABIZENA         object
# ADINA          float64
# ADIN TARTEA     object
# ESKARMENTUA    float64
# ALTUERA        float64
# MASA           float64
# MAILA           object
# ESTILOA         object
# PRESA           object
# dtype: object

# %%
eskaladaDB.describe()
# Out:
#               ADINA   ESKARMENTUA       ALTUERA          MASA
# count  12000.000000  12000.000000  12000.000000  12000.000000
# mean      28.107333      5.475750    170.094667     70.103414
# std       10.658828      5.296343      9.786378      9.405626
# min       14.000000      0.000000    145.000000     45.010000
# 25%       19.000000      2.000000    163.000000     63.367500
# 50%       26.000000      4.000000    170.000000     70.915000
# 75%       34.000000      8.000000    177.000000     77.130000
# max       55.000000     48.000000    195.000000     89.980000

# %%
eskaladaDB.describe(include=["O"])
# Out:
#          SEXUA  IZENA  ABIZENA ADIN TARTEA       MAILA  ESTILOA  PRESA
# count    12000  12000    12000       12000       12000    12000  12000
# unique       2    149      101           3           5        3      9
# top     Gizona  ANGEL  NAVARRO      Gaztea  Aurreratua  Nahasia  Pinch
# freq      7207    164      154        5973        4247     4042   2096

# %%
eskaladaDB.groupby(["ADINA"]).count()
# Out:
#        SEXUA  IZENA  ABIZENA  ADIN TARTEA  ESKARMENTUA  ALTUERA  MASA  MAILA  \
# ADINA
# 14.0     484    484      484          484          484      484   484    484
# 15.0     510    510      510          510          510      510   510    510
# 16.0     507    507      507          507          507      507   507    507
# 17.0     566    566      566          566          566      566   566    566
# 18.0     543    543      543          543          543      543   543    543
# 19.0     499    499      499          499          499      499   499    499
# 20.0     546    546      546          546          546      546   546    546
# 21.0     405    405      405          405          405      405   405    405
# 22.0     396    396      396          396          396      396   396    396
# 23.0     385    385      385          385          385      385   385    385
# 24.0     358    358      358          358          358      358   358    358
# 25.0     448    448      448          448          448      448   448    448
# 26.0     400    400      400          400          400      400   400    400
# 27.0     387    387      387          387          387      387   387    387
# 28.0     423    423      423          423          423      423   423    423
# 29.0     406    406      406          406          406      406   406    406
# 30.0     404    404      404          404          404      404   404    404
# 31.0     393    393      393          393          393      393   393    393
# 32.0     384    384      384          384          384      384   384    384
# 33.0     415    415      415          415          415      415   415    415
# 34.0     392    392      392          392          392      392   392    392
# 35.0     376    376      376          376          376      376   376    376
# 36.0     117    117      117          117          117      117   117    117
# 37.0     117    117      117          117          117      117   117    117
# 38.0     119    119      119          119          119      119   119    119
# 39.0     120    120      120          120          120      120   120    120
# 40.0     140    140      140          140          140      140   140    140
# 41.0     111    111      111          111          111      111   111    111
# 42.0     109    109      109          109          109      109   109    109
# 43.0     123    123      123          123          123      123   123    123
# 44.0     116    116      116          116          116      116   116    116
# 45.0     120    120      120          120          120      120   120    120
# 46.0     132    132      132          132          132      132   132    132
# 47.0     131    131      131          131          131      131   131    131
# 48.0     101    101      101          101          101      101   101    101
# 49.0     109    109      109          109          109      109   109    109
# 50.0     118    118      118          118          118      118   118    118
# 51.0     120    120      120          120          120      120   120    120
# 52.0     123    123      123          123          123      123   123    123
# 53.0     106    106      106          106          106      106   106    106
# 54.0     124    124      124          124          124      124   124    124
# 55.0     117    117      117          117          117      117   117    117
#
#        ESTILOA  PRESA
# ADINA
# 14.0       484    484
# 15.0       510    510
# 16.0       507    507
# 17.0       566    566
# 18.0       543    543
# 19.0       499    499
# 20.0       546    546
# 21.0       405    405
# 22.0       396    396
# 23.0       385    385
# 24.0       358    358
# 25.0       448    448
# 26.0       400    400
# 27.0       387    387
# 28.0       423    423
# 29.0       406    406
# 30.0       404    404
# 31.0       393    393
# 32.0       384    384
# 33.0       415    415
# 34.0       392    392
# 35.0       376    376
# 36.0       117    117
# 37.0       117    117
# 38.0       119    119
# 39.0       120    120
# 40.0       140    140
# 41.0       111    111
# 42.0       109    109
# 43.0       123    123
# 44.0       116    116
# 45.0       120    120
# 46.0       132    132
# 47.0       131    131
# 48.0       101    101
# 49.0       109    109
# 50.0       118    118
# 51.0       120    120
# 52.0       123    123
# 53.0       106    106
# 54.0       124    124
# 55.0       117    117

# %%
eskaladaDB.groupby(["MAILA", "SEXUA"]).count()["ADINA"].unstack(level=0)
# Out:
# MAILA     Aurreratua  Elitea  Erdikoa  Hasiberria  Profesionala
# SEXUA
# Emakumea        1704     164     1616         788           521
# Gizona          2543     309     2170        1285           900

# %%
eskaladaDB.groupby(["MAILA", "SEXUA"]).count()["ESTILOA"].unstack(level=1)
# Out:
# SEXUA         Emakumea  Gizona
# MAILA
# Aurreratua        1704    2543
# Elitea             164     309
# Erdikoa           1616    2170
# Hasiberria         788    1285
# Profesionala       521     900

# %%
grouped_gender = eskaladaDB.groupby(["MAILA", "SEXUA"]).count()["ADINA"]
(grouped_gender.unstack(level=1).plot.bar())
plt.show()

# %%
grouped_gender = eskaladaDB.groupby(["MAILA", "ESTILOA"]).count()["SEXUA"]
(grouped_gender.unstack(level=0).plot.bar())
plt.show()

# %%
grouped_gender = eskaladaDB.groupby(["ADIN TARTEA", "MAILA"]).count()["SEXUA"]
(grouped_gender.unstack(level=0).plot.bar())
plt.show()

# %%
# DEFINITU TEXTUA ZENBAKIETAN
aldatuta_eskaladaDB = eskaladaDB.copy()

# DEFINITU SEXUAK ZENBAKIETAN
sexuak_zenbakietan = {
    "Emakumea": 0,
    "Gizona": 1
}

aldatuta_eskaladaDB["SEXUA"] = aldatuta_eskaladaDB["SEXUA"].map(sexuak_zenbakietan).astype(int)

# IZENAK ETA ABIZENAK KENDU
aldatuta_eskaladaDB = aldatuta_eskaladaDB.drop(["IZENA", "ABIZENA"], axis=1)

# DEFINITU ADIN TARTEA ZENBAKIETAN
adin_tartea_zenbakietan = {
    "Nerabea": 0,
    "Gaztea": 1,
    "Heldua": 2
}

aldatuta_eskaladaDB["ADIN TARTEA"] = aldatuta_eskaladaDB["ADIN TARTEA"].map(adin_tartea_zenbakietan).astype(int)

# DEFINITU MAILA ZENBAKIETAN
maila_zenbakietan = {
    "Hasiberria": 0,
    "Erdikoa": 1,
    "Aurreratua": 2,
    "Profesionala": 3,
    "Elitea": 4
}

aldatuta_eskaladaDB["MAILA"] = aldatuta_eskaladaDB["MAILA"].map(maila_zenbakietan).astype(int)

# DEFINITU ESTILOA ZENBAKIETAN
estiloa_zenbakietan = {
    "Dinamikoa": 0,
    "Estatikoa": 1,
    "Nahasia": 2
}

aldatuta_eskaladaDB["ESTILOA"] = aldatuta_eskaladaDB["ESTILOA"].map(estiloa_zenbakietan).astype(int)

# DEFINITU PRESAK ZENBAKIETAN
presak = ["Jug", "Crimp", "Sloper", "Pinch", "Pocket", "Crack", "Volume", "Mono", "Edge"]
presen_luzeera = len(presak)
presen_luzeeraren_zerrenda = []
while presen_luzeera > 0:
    presen_luzeeraren_zerrenda.append(len(presak)-presen_luzeera)
    presen_luzeera -= 1
presak_zenbakietan = dict(zip(presak, presen_luzeeraren_zerrenda))

aldatuta_eskaladaDB["PRESA"] = aldatuta_eskaladaDB["PRESA"].map(presak_zenbakietan).astype(int)

# ERAKUTSI DATUAK ALDATUTA
aldatuta_eskaladaDB
# Out:
#        SEXUA  ADINA  ADIN TARTEA  ESKARMENTUA  ALTUERA   MASA  MAILA  ESTILOA  \
# 0          1   25.0            1          3.0    179.0  87.96      2        0
# 1          1   38.0            2          3.0    183.0  77.13      2        2
# 2          0   15.0            0          7.0    162.0  57.35      2        2
# 3          0   16.0            0          0.0    158.0  46.72      0        2
# 4          1   14.0            0          6.0    169.0  67.99      2        0
# ...      ...    ...          ...          ...      ...    ...    ...      ...
# 11995      1   53.0            2          0.0    181.0  70.24      2        1
# 11996      1   21.0            1          1.0    160.0  79.49      1        0
# 11997      1   36.0            2          9.0    177.0  76.12      2        1
# 11998      1   29.0            1          8.0    164.0  70.94      3        0
# 11999      1   30.0            1          7.0    173.0  75.51      4        0
#
#        PRESA
# 0          1
# 1          5
# 2          2
# 3          0
# 4          6
# ...      ...
# 11995      3
# 11996      1
# 11997      3
# 11998      1
# 11999      8
#
# [12000 rows x 9 columns]

# %%
aldatuta_eskaladaDB.describe()
# Out:
#               SEXUA         ADINA   ADIN TARTEA   ESKARMENTUA       ALTUERA  \
# count  12000.000000  12000.000000  12000.000000  12000.000000  12000.000000
# mean       0.600583     28.107333      0.893250      5.475750    170.094667
# std        0.489799     10.658828      0.700639      5.296343      9.786378
# min        0.000000     14.000000      0.000000      0.000000    145.000000
# 25%        0.000000     19.000000      0.000000      2.000000    163.000000
# 50%        1.000000     26.000000      1.000000      4.000000    170.000000
# 75%        1.000000     34.000000      1.000000      8.000000    177.000000
# max        1.000000     55.000000      2.000000     48.000000    195.000000
#
#                MASA         MAILA       ESTILOA         PRESA
# count  12000.000000  12000.000000  12000.000000  12000.000000
# mean      70.103414      1.536250      1.009583      3.300000
# std        9.405626      1.033251      0.814891      2.606959
# min       45.010000      0.000000      0.000000      0.000000
# 25%       63.367500      1.000000      0.000000      1.000000
# 50%       70.915000      2.000000      1.000000      3.000000
# 75%       77.130000      2.000000      2.000000      6.000000
# max       89.980000      4.000000      2.000000      8.000000

# %%
aldatuta_eskaladaDB.to_csv("Aldatuta Eskalada-DB.csv", index=False)

# %%
import seaborn as sns

# %%
sns.distplot(aldatuta_eskaladaDB["PRESA"])
# Out:
# C:\Users\dipas\AppData\Local\Temp\ipykernel_4260\2194953449.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(aldatuta_eskaladaDB["PRESA"])
# <Axes: xlabel='PRESA', ylabel='Density'>

# %%
aldatuta_eskaladaDB.plot.scatter(x="MAILA", y="ALTUERA");
